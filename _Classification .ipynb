# %% [markdown]
# # PROJECT NAME

# %% [markdown]
# ## Predict Average Price and type of Avocado by using Avocado Prices dataset

# %% [markdown]
# # AVOCADO DATA STRUCTURE FOR CLASSIFICATION MODEL

# %% [markdown]
# # Preprocessing a data structure

# %%
import pandas as pd

# %% [markdown]
# ## Load dataset

# %%
df=pd.read_csv("avocado.csv")
df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %% [markdown]
# ## Print Dataset

# %%
df=pd.read_csv("avocado.csv")
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
df=pd.read_csv("avocado.csv")
df.tail(10)
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046     4225  \
# 18239           2  2018-03-11          1.56      22128.42  2162.67  3194.25
# 18240           3  2018-03-04          1.54      17393.30  1832.24  1905.57
# 18241           4  2018-02-25          1.57      18421.24  1974.26  2482.65
# 18242           5  2018-02-18          1.56      17597.12  1892.05  1928.36
# 18243           6  2018-02-11          1.57      15986.17  1924.28  1368.32
# 18244           7  2018-02-04          1.63      17074.83  2046.96  1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70  3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92  2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63  2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77  2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# ...

# %% [markdown]
# ## Shape Dataset

# %%
df.shape
# Out:
# (18249, 14)

# %% [markdown]
# ## Info of dataset

# %%
df.info
# Out:
# <bound method DataFrame.info of        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB

# %% [markdown]
# ## Columns Name

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %% [markdown]
# ## Change Column Name

# %%
df=df.rename (columns={"type":"type of avocado"})
df.head(5)
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags type of avocado  \
# 0   48.16     8696.87     8603.62       93.25          0.0    conventional
# 1   58.33     9505.56     9408.07       97.49          0.0    conventional
# 2  130.50     8145.35     8042.21      103.14          0.0    conventional
# 3   72.58     5811.16     5677.40      133.76          0.0    conventional
# 4   75.78     6183.95     5986.26      197.69          0.0    conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %% [markdown]
# ## Show Single Column

# %%
df["AveragePrice"]
# Out:
# 0        1.33
# 1        1.35
# 2        0.93
# 3        1.08
# 4        1.28
#          ...
# 18244    1.63
# 18245    1.71
# 18246    1.87
# 18247    1.93
# 18248    1.62
# Name: AveragePrice, Length: 18249, dtype: float64

# %%
df["type of avocado"]
# Out:
# 0        conventional
# 1        conventional
# 2        conventional
# 3        conventional
# 4        conventional
#              ...
# 18244         organic
# 18245         organic
# 18246         organic
# 18247         organic
# 18248         organic
# Name: type of avocado, Length: 18249, dtype: object

# %% [markdown]
# ## Replace Null Value

# %% [markdown]
# ### Apply isna()

# %%
df.isna()
# Out:
#        Unnamed: 0   Date  AveragePrice  Total Volume   4046   4225   4770  \
# 0           False  False         False         False  False  False  False
# 1           False  False         False         False  False  False  False
# 2           False  False         False         False  False  False  False
# 3           False  False         False         False  False  False  False
# 4           False  False         False         False  False  False  False
# ...           ...    ...           ...           ...    ...    ...    ...
# 18244       False  False         False         False  False  False  False
# 18245       False  False         False         False  False  False  False
# 18246       False  False         False         False  False  False  False
# 18247       False  False         False         False  False  False  False
# 18248       False  False         False         False  False  False  False
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags  type of avocado  \
# ...

# %% [markdown]
# ### Apply isna.sum()

# %%
df.isna().sum()
# Out:
# Unnamed: 0         0
# Date               0
# AveragePrice       0
# Total Volume       0
# 4046               0
# 4225               0
# 4770               0
# Total Bags         0
# Small Bags         0
# Large Bags         0
# XLarge Bags        0
# type of avocado    0
# year               0
# region             0
# dtype: int64

# %%
df["Small Bags"]=df["Small Bags"].interpolate()
df.isna().sum()
# Out:
# Unnamed: 0         0
# Date               0
# AveragePrice       0
# Total Volume       0
# 4046               0
# 4225               0
# 4770               0
# Total Bags         0
# Small Bags         0
# Large Bags         0
# XLarge Bags        0
# type of avocado    0
# year               0
# region             0
# dtype: int64

# %% [markdown]
# ### Apply isna.sum.sum()

# %%
df.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# ## Mean & Median

# %%
df["Total Bags"].fillna(value=df["Total Bags"].mean())
# Out:
# 0         8696.87
# 1         9505.56
# 2         8145.35
# 3         5811.16
# 4         6183.95
#            ...
# 18244    13498.67
# 18245     9264.84
# 18246     9394.11
# 18247    10969.54
# 18248    12014.15
# Name: Total Bags, Length: 18249, dtype: float64

# %%
df.count()
# Out:
# Unnamed: 0         18249
# Date               18249
# AveragePrice       18249
# Total Volume       18249
# 4046               18249
# 4225               18249
# 4770               18249
# Total Bags         18249
# Small Bags         18249
# Large Bags         18249
# XLarge Bags        18249
# type of avocado    18249
# year               18249
# region             18249
# dtype: int64

# %% [markdown]
# ## Drop column

# %%
df=df.drop(["Date","Unnamed: 0"],axis=1)
df
# Out:
#        AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0              1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1              1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2              0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3              1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4              1.28      51039.60   941.48   43838.39   75.78     6183.95
# ...             ...           ...      ...        ...     ...         ...
# 18244          1.63      17074.83  2046.96    1529.20    0.00    13498.67
# 18245          1.71      13888.04  1191.70    3431.50    0.00     9264.84
# 18246          1.87      13766.76  1191.92    2452.79  727.94     9394.11
# 18247          1.93      16205.22  1527.63    2981.04  727.01    10969.54
# 18248          1.62      17489.58  2894.77    2356.13  224.53    12014.15
#
#        Small Bags  Large Bags  XLarge Bags type of avocado  year  \
# ...

# %% [markdown]
# ## Shape dataset When call info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   AveragePrice     18249 non-null  float64
#  1   Total Volume     18249 non-null  float64
#  2   4046             18249 non-null  float64
#  3   4225             18249 non-null  float64
#  4   4770             18249 non-null  float64
#  5   Total Bags       18249 non-null  float64
#  6   Small Bags       18249 non-null  float64
#  7   Large Bags       18249 non-null  float64
#  8   XLarge Bags      18249 non-null  float64
#  9   type of avocado  18249 non-null  object
#  10  year             18249 non-null  int64
#  11  region           18249 non-null  object
# dtypes: float64(9), int64(1), object(2)
# memory usage: 1.7+ MB

# %% [markdown]
# ## Convert Categorical in numerical

# %%
df["type of avocado"].value_counts()
# Out:
# type of avocado
# conventional    9126
# organic         9123
# Name: count, dtype: int64

# %%
df["type of avocado"]=df["type of avocado"].replace({"conventional":"0","organic":"1"})
df
# Out:
#        AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0              1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1              1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2              0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3              1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4              1.28      51039.60   941.48   43838.39   75.78     6183.95
# ...             ...           ...      ...        ...     ...         ...
# 18244          1.63      17074.83  2046.96    1529.20    0.00    13498.67
# 18245          1.71      13888.04  1191.70    3431.50    0.00     9264.84
# 18246          1.87      13766.76  1191.92    2452.79  727.94     9394.11
# 18247          1.93      16205.22  1527.63    2981.04  727.01    10969.54
# 18248          1.62      17489.58  2894.77    2356.13  224.53    12014.15
#
#        Small Bags  Large Bags  XLarge Bags type of avocado  year  \
# ...

# %% [markdown]
# ## Filter and Data set

# %%
df["type of avocado"]=="0"
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 18244    False
# 18245    False
# 18246    False
# 18247    False
# 18248    False
# Name: type of avocado, Length: 18249, dtype: bool

# %%
df[df["type of avocado"]=="0"]
# Out:
#       AveragePrice  Total Volume       4046       4225      4770  Total Bags  \
# 0             1.33      64236.62    1036.74   54454.85     48.16     8696.87
# 1             1.35      54876.98     674.28   44638.81     58.33     9505.56
# 2             0.93     118220.22     794.70  109149.67    130.50     8145.35
# 3             1.08      78992.15    1132.00   71976.41     72.58     5811.16
# 4             1.28      51039.60     941.48   43838.39     75.78     6183.95
# ...            ...           ...        ...        ...       ...         ...
# 9121          0.76    1272039.80  531469.08  368948.26  13078.20   358544.26
# 9122          0.85     957086.16  479147.93  179489.19   7314.98   291134.06
# 9123          0.84    1020913.20  505263.29  177911.40   9468.95   328269.56
# 9124          0.90     950954.60  463945.73  188126.02  11227.47   287655.38
# 9125          0.88     880266.52  436282.38  178669.53   9467.11   255847.50
#
# ...

# %%
df["type of avocado"]=="1"
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 18244     True
# 18245     True
# 18246     True
# 18247     True
# 18248     True
# Name: type of avocado, Length: 18249, dtype: bool

# %%
df[df["type of avocado"]=="1"]
# Out:
#        AveragePrice  Total Volume     4046     4225    4770  Total Bags  \
# 9126           1.83        989.55     8.16    88.59    0.00      892.80
# 9127           1.89       1163.03    30.24   172.14    0.00      960.65
# 9128           1.85        995.96    10.44   178.70    0.00      806.82
# 9129           1.84       1158.42    90.29   104.18    0.00      963.95
# 9130           1.94        831.69     0.00    94.73    0.00      736.96
# ...             ...           ...      ...      ...     ...         ...
# 18244          1.63      17074.83  2046.96  1529.20    0.00    13498.67
# 18245          1.71      13888.04  1191.70  3431.50    0.00     9264.84
# 18246          1.87      13766.76  1191.92  2452.79  727.94     9394.11
# 18247          1.93      16205.22  1527.63  2981.04  727.01    10969.54
# 18248          1.62      17489.58  2894.77  2356.13  224.53    12014.15
#
#        Small Bags  Large Bags  XLarge Bags type of avocado  year  \
# ...

# %% [markdown]
# ## Convert Categorical to Numerical value

# %%
 from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for column in df.columns:
    if df[column].dtype=='object':  #check if the column is object
        df[column]=le.fit_transform(df[column])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   AveragePrice     18249 non-null  float64
#  1   Total Volume     18249 non-null  float64
#  2   4046             18249 non-null  float64
#  3   4225             18249 non-null  float64
#  4   4770             18249 non-null  float64
#  5   Total Bags       18249 non-null  float64
#  6   Small Bags       18249 non-null  float64
#  7   Large Bags       18249 non-null  float64
#  8   XLarge Bags      18249 non-null  float64
#  9   type of avocado  18249 non-null  int32
#  10  year             18249 non-null  int64
#  11  region           18249 non-null  int32
# dtypes: float64(9), int32(2), int64(1)
# memory usage: 1.5 MB

# %%
# get information of specific rowon the base of index
df.iloc[1:3]
# Out:
#    AveragePrice  Total Volume    4046       4225    4770  Total Bags  \
# 1          1.35      54876.98  674.28   44638.81   58.33     9505.56
# 2          0.93     118220.22  794.70  109149.67  130.50     8145.35
#
#    Small Bags  Large Bags  XLarge Bags  type of avocado  year  region
# 1     9408.07       97.49          0.0                0  2015       0
# 2     8042.21      103.14          0.0                0  2015       0

# %% [markdown]
# # Data Conversion

# %% [markdown]
# ## Separate X & Y Using Numpy

# %%
import numpy as np

# %%
X=df[["AveragePrice","Total Volume","4046","4225","4770","Total Bags","Small Bags","Large Bags","XLarge Bags","region"]].values
X[0:5]
# Out:
# array([[1.3300000e+00, 6.4236620e+04, 1.0367400e+03, 5.4454850e+04,
#         4.8160000e+01, 8.6968700e+03, 8.6036200e+03, 9.3250000e+01,
#         0.0000000e+00, 0.0000000e+00],
#        [1.3500000e+00, 5.4876980e+04, 6.7428000e+02, 4.4638810e+04,
#         5.8330000e+01, 9.5055600e+03, 9.4080700e+03, 9.7490000e+01,
#         0.0000000e+00, 0.0000000e+00],
#        [9.3000000e-01, 1.1822022e+05, 7.9470000e+02, 1.0914967e+05,
#         1.3050000e+02, 8.1453500e+03, 8.0422100e+03, 1.0314000e+02,
#         0.0000000e+00, 0.0000000e+00],
#        [1.0800000e+00, 7.8992150e+04, 1.1320000e+03, 7.1976410e+04,
#         7.2580000e+01, 5.8111600e+03, 5.6774000e+03, 1.3376000e+02,
#         0.0000000e+00, 0.0000000e+00],
#        [1.2800000e+00, 5.1039600e+04, 9.4148000e+02, 4.3838390e+04,
#         7.5780000e+01, 6.1839500e+03, 5.9862600e+03, 1.9769000e+02,
#         0.0000000e+00, 0.0000000e+00]])

# %%
Y = df['type of avocado'].values
Y
# Out:
# array([0, 0, 0, ..., 1, 1, 1])

# %%
X=df.drop(["type of avocado"],axis=1)
Y=df["type of avocado"]
X.head()
# Out:
#    AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0          1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1          1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2          0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3          1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4          1.28      51039.60   941.48   43838.39   75.78     6183.95
#
#    Small Bags  Large Bags  XLarge Bags  year  region
# 0     8603.62       93.25          0.0  2015       0
# 1     9408.07       97.49          0.0  2015       0
# 2     8042.21      103.14          0.0  2015       0
# 3     5677.40      133.76          0.0  2015       0
# 4     5986.26      197.69          0.0  2015       0

# %% [markdown]
# # Standarized Data

# %%
from sklearn.preprocessing import StandardScaler
Aroosa= StandardScaler()
X_scaled= Aroosa.fit_transform(X)
X_scaled[1]
# Out:
# array([-0.13901962, -0.23042664, -0.23110251, -0.20805446, -0.21199672,
#        -0.23335029, -0.23156838, -0.22233464, -0.17557961, -1.22128204,
#        -1.7002522 ])

# %% [markdown]
# # Correlation

# %%
# understand the correlation between various features
# Positive correlation
# Negative correlation
correlation=df.corr()
correlation
# Out:
#                  AveragePrice  Total Volume      4046      4225      4770  \
# AveragePrice         1.000000     -0.192752 -0.208317 -0.172928 -0.179446
# Total Volume        -0.192752      1.000000  0.977863  0.974181  0.872202
# 4046                -0.208317      0.977863  1.000000  0.926110  0.833389
# 4225                -0.172928      0.974181  0.926110  1.000000  0.887855
# 4770                -0.179446      0.872202  0.833389  0.887855  1.000000
# Total Bags          -0.177088      0.963047  0.920057  0.905787  0.792314
# Small Bags          -0.174730      0.967238  0.925280  0.916031  0.802733
# Large Bags          -0.172940      0.880640  0.838645  0.810015  0.698471
# XLarge Bags         -0.117592      0.747157  0.699377  0.688809  0.679861
# type of avocado      0.615845     -0.232434 -0.225819 -0.232289 -0.210027
# year                 0.093197      0.017193  0.003353 -0.009559 -0.036531
# region              -0.011716      0.174176  0.192073  0.145726  0.095252
#
# ...

# %% [markdown]
# ## Heat Map of Correlation

# %%
# Constructing a heatmap to understand the correlation
import matplotlib.pyplot as plt 
import seaborn as sns
plt.figure(figsize=(15,15))
sns.heatmap(correlation, cbar=True, square=True, fmt='.1f', annot=True, annot_kws={'size':10}, cmap='Greens')
# Out:
# <Axes: >

# %%
df=df.drop(["year"], axis=1)
df
# Out:
#        AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0              1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1              1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2              0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3              1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4              1.28      51039.60   941.48   43838.39   75.78     6183.95
# ...             ...           ...      ...        ...     ...         ...
# 18244          1.63      17074.83  2046.96    1529.20    0.00    13498.67
# 18245          1.71      13888.04  1191.70    3431.50    0.00     9264.84
# 18246          1.87      13766.76  1191.92    2452.79  727.94     9394.11
# 18247          1.93      16205.22  1527.63    2981.04  727.01    10969.54
# 18248          1.62      17489.58  2894.77    2356.13  224.53    12014.15
#
#        Small Bags  Large Bags  XLarge Bags  type of avocado  region
# ...

# %%
correlation=df.corr()
correlation
# Out:
#                  AveragePrice  Total Volume      4046      4225      4770  \
# AveragePrice         1.000000     -0.192752 -0.208317 -0.172928 -0.179446
# Total Volume        -0.192752      1.000000  0.977863  0.974181  0.872202
# 4046                -0.208317      0.977863  1.000000  0.926110  0.833389
# 4225                -0.172928      0.974181  0.926110  1.000000  0.887855
# 4770                -0.179446      0.872202  0.833389  0.887855  1.000000
# Total Bags          -0.177088      0.963047  0.920057  0.905787  0.792314
# Small Bags          -0.174730      0.967238  0.925280  0.916031  0.802733
# Large Bags          -0.172940      0.880640  0.838645  0.810015  0.698471
# XLarge Bags         -0.117592      0.747157  0.699377  0.688809  0.679861
# type of avocado      0.615845     -0.232434 -0.225819 -0.232289 -0.210027
# region              -0.011716      0.174176  0.192073  0.145726  0.095252
#
#                  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# ...

# %%
import matplotlib.pyplot as plt 
import seaborn as sns
plt.figure(figsize=(15,15))
sns.heatmap(correlation, cbar=True, square=True, fmt='.1f', annot=True, annot_kws={'size':10}, cmap='Greens')
# Out:
# <Axes: >

# %% [markdown]
# # Data Split

# %%
 from sklearn.model_selection import train_test_split
X_TRAIN, X_TEST,Y_TRAIN,Y_TEST = train_test_split(X_scaled,Y, test_size=0.25, random_state=25)

print("Size of Train X= ",len(X_TRAIN))
print("Size of Train Y= ",len(Y_TRAIN))
print("Size of Train X= ",len(X_TEST))
print("Size of Train Y= ",len(Y_TEST))
# Out:
# Size of Train X=  13686
# Size of Train Y=  13686
# Size of Train X=  4563
# Size of Train Y=  4563

# %% [markdown]
# # Apply PCA

# %%
from sklearn.decomposition import PCA
pca= PCA(n_components=7)
X_pca = pca.fit_transform(X_scaled)
X_pca.shape
# Out:
# (18249, 7)

# %%
 from sklearn.model_selection import train_test_split
X_TRAIN, X_TEST,Y_TRAIN,Y_TEST = train_test_split(X_pca,Y, test_size=0.25, random_state=25)

print("Size of Train X= ",len(X_TRAIN))
print("Size of Train Y= ",len(Y_TRAIN))
print("Size of Train X= ",len(X_TEST))
print("Size of Train Y= ",len(Y_TEST))
# Out:
# Size of Train X=  13686
# Size of Train Y=  13686
# Size of Train X=  4563
# Size of Train Y=  4563

# %% [markdown]
# # CLASSIFICATION MODEL

# %% [markdown]
# # 1.Naive Bayes/Gaussian Navie Bayes Model

# %% [markdown]
# ## Model Training

# %%
from sklearn.naive_bayes import GaussianNB
Aroosa =  GaussianNB()
Aroosa.fit(X_TRAIN, Y_TRAIN)
GaussianNB()
# Out:
# GaussianNB()

# %%
y_pred=Aroosa.predict(X_TRAIN)
print(y_pred)
# Out:
# [0 1 0 ... 0 1 0]

# %%
print(Y_TRAIN)
# Out:
# 5208     0
# 18131    1
# 1539     0
# 4401     0
# 812      0
#         ..
# 7324     0
# 1160     0
# 1175     0
# 2934     0
# 6618     0
# Name: type of avocado, Length: 13686, dtype: int32

# %% [markdown]
# ##  Training Accuracy

# %%
from sklearn.metrics import accuracy_score
accuracy= accuracy_score(Y_TRAIN,y_pred)
print("The Accuracy of Prediction on S is ", accuracy)
# Out:
# The Accuracy of Prediction on S is  0.6989624433727897

# %% [markdown]
# ## Confusion Matrix

# %%
from sklearn.metrics import classification_report,confusion_matrix
confusion_matrix(Y_TRAIN, y_pred)
# Out:
# array([[2867, 3985],
#        [ 135, 6699]], dtype=int64)

# %%
import matplotlib.pyplot as plt
cm = confusion_matrix(Y_TRAIN, y_pred)
fig, ax= plt.subplots(figsize=(4,4))
ax.imshow(cm)
ax.xaxis.set(ticks=(0,1), ticklabels=('predicted 0s','predicted 1s'))
ax.yaxis.set(ticks=(0,1), ticklabels=('Actual 0s','Actual 1s'))  
ax.set_ylim(1.5 ,-0.5)
for i in range(2):
    for j in range(2):
        ax.text(j,i,cm[i,j],  color='red')
plt.show()

# %% [markdown]
# ## Model Testing

# %%
# Make predictions on the testing data 
y_pred = Aroosa.predict(X_TEST)
print(y_pred)
# Out:
# [1 1 1 ... 1 1 1]

# %%
print(Y_TEST)
# Out:
# 11225    1
# 16263    1
# 15953    1
# 4810     0
# 12672    1
#         ..
# 5698     0
# 15869    1
# 1046     0
# 15516    1
# 3854     0
# Name: type of avocado, Length: 4563, dtype: int32

# %% [markdown]
# ## Calculate Accuracy of Model

# %%
from sklearn.metrics import accuracy_score
accuracy= accuracy_score(Y_TEST,y_pred)
print("The Accuracy of Prediction on S is ", accuracy)
# Out:
# The Accuracy of Prediction on S is  0.6903353057199211

# %% [markdown]
# ## Confusion Matrix

# %%
from sklearn.metrics import classification_report,confusion_matrix
confusion_matrix(Y_TEST, y_pred)
# Out:
# array([[ 909, 1365],
#        [  48, 2241]], dtype=int64)

# %%
import matplotlib.pyplot as plt
cm = confusion_matrix(Y_TEST, y_pred)
fig, ax= plt.subplots(figsize=(4,4))
ax.imshow(cm)
ax.xaxis.set(ticks=(0,1), ticklabels=('predicted 0s','predicted 1s'))
ax.yaxis.set(ticks=(0,1), ticklabels=('Actual 0s','Actual 1s'))  
ax.set_ylim(1.5 ,-0.5)
for i in range(2):
    for j in range(2):
        ax.text(j,i,cm[i,j],  color='red')
plt.show()

# %% [markdown]
# ## Classfication Report

# %%
report=classification_report(Y_TEST,y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.40      0.56      2274
#            1       0.62      0.98      0.76      2289
#
#     accuracy                           0.69      4563
#    macro avg       0.79      0.69      0.66      4563
# weighted avg       0.79      0.69      0.66      4563

# %% [markdown]
# # 2.Logistic Regression Model

# %% [markdown]
# ## Model Training

# %%
from sklearn.linear_model import LogisticRegression
Aroosa=LogisticRegression(solver="liblinear", random_state=25)
Aroosa.fit(X_TRAIN, Y_TRAIN)
# Out:
# LogisticRegression(random_state=25, solver='liblinear')

# %%
Aroosa.classes_
# Out:
# array([0, 1])

# %% [markdown]
# ## Value of Intercept & Coeficient

# %% [markdown]
# ### Y_Model=W0+W1*X

# %%
Aroosa.intercept_
# Out:
# array([-8.05295811])

# %%
Aroosa.coef_
# Out:
# array([[-15.14538981,   2.2133904 ,  -2.46705413,  -1.55436219,
#           5.24654885, -12.63485808,   2.63033538]])

# %%
df.columns
# Out:
# Index(['AveragePrice', 'Total Volume', '4046', '4225', '4770', 'Total Bags',
#        'Small Bags', 'Large Bags', 'XLarge Bags', 'type of avocado', 'region'],
#       dtype='object')

# %%
y_pred=Aroosa.predict(X_TRAIN)
print(y_pred)
# Out:
# [0 1 0 ... 0 0 0]

# %%
print(Y_TRAIN)
# Out:
# 5208     0
# 18131    1
# 1539     0
# 4401     0
# 812      0
#         ..
# 7324     0
# 1160     0
# 1175     0
# 2934     0
# 6618     0
# Name: type of avocado, Length: 13686, dtype: int32

# %% [markdown]
# ## Training Accuracy

# %%
from sklearn.metrics import accuracy_score
accuracy= accuracy_score(Y_TRAIN,y_pred)
print("The Accuracy of Prediction on S is ", accuracy)
# Out:
# The Accuracy of Prediction on S is  0.9087388572263627

# %% [markdown]
# ## Confusion Metrix

# %%
from sklearn.metrics import classification_report,confusion_matrix
confusion_matrix(Y_TRAIN, y_pred)
# Out:
# array([[6062,  790],
#        [ 459, 6375]], dtype=int64)

# %%
import matplotlib.pyplot as plt
cm = confusion_matrix(Y_TRAIN, y_pred)
fig, ax= plt.subplots(figsize=(4,4))
ax.imshow(cm)
ax.xaxis.set(ticks=(0,1), ticklabels=('predicted 0s','predicted 1s'))
ax.yaxis.set(ticks=(0,1), ticklabels=('Actual 0s','Actual 1s'))  
ax.set_ylim(1.5 ,-0.5)
for i in range(2):
    for j in range(2):
        ax.text(j,i,cm[i,j],  color='red')
plt.show()

# %% [markdown]
# ## Model Testing

# %%
# Make predictions on the testing data 
y_pred = Aroosa.predict(X_TEST)
print(y_pred)
# Out:
# [1 1 0 ... 1 1 1]

# %%
print(Y_TEST)
# Out:
# 11225    1
# 16263    1
# 15953    1
# 4810     0
# 12672    1
#         ..
# 5698     0
# 15869    1
# 1046     0
# 15516    1
# 3854     0
# Name: type of avocado, Length: 4563, dtype: int32

# %% [markdown]
# ## Calculate Accuracy of model

# %%
from sklearn.metrics import accuracy_score
accuracy= accuracy_score(Y_TEST,y_pred)
print("The Accuracy of Prediction on S is ", accuracy)
# Out:
# The Accuracy of Prediction on S is  0.9029147490685953

# %% [markdown]
# ## Confusion Matrix

# %%
from sklearn.metrics import classification_report,confusion_matrix
confusion_matrix(Y_TEST, y_pred)
# Out:
# array([[1978,  296],
#        [ 147, 2142]], dtype=int64)

# %%
import matplotlib.pyplot as plt
cm = confusion_matrix(Y_TEST, y_pred)
fig, ax= plt.subplots(figsize=(4,4))
ax.imshow(cm)
ax.xaxis.set(ticks=(0,1), ticklabels=('predicted 0s','predicted 1s'))
ax.yaxis.set(ticks=(0,1), ticklabels=('Actual 0s','Actual 1s'))  
ax.set_ylim(1.5 ,-0.5)
for i in range(2):
    for j in range(2):
        ax.text(j,i,cm[i,j],  color='red')
plt.show()

# %% [markdown]
# ## Classification Report

# %%
report=classification_report(Y_TEST,y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.87      0.90      2274
#            1       0.88      0.94      0.91      2289
#
#     accuracy                           0.90      4563
#    macro avg       0.90      0.90      0.90      4563
# weighted avg       0.90      0.90      0.90      4563

# %% [markdown]
# # 3.Support Vector Machine Model

# %% [markdown]
# ## Model Training

# %%
# import svm model
from sklearn import svm

# %%
# create a svm classfier
Aroosa=svm.SVC(kernel='linear') # linear kernel

# %%
# Train the model using the training sets
Aroosa.fit(X_TRAIN,Y_TRAIN)
# Out:
# SVC(kernel='linear')

# %%
y_pred = Aroosa.predict(X_TRAIN)
print(y_pred)
# Out:
# [0 1 0 ... 0 0 0]

# %%
print(Y_TRAIN)
# Out:
# 5208     0
# 18131    1
# 1539     0
# 4401     0
# 812      0
#         ..
# 7324     0
# 1160     0
# 1175     0
# 2934     0
# 6618     0
# Name: type of avocado, Length: 13686, dtype: int32

# %% [markdown]
# ## Training Accuracy

# %%
from sklearn.metrics import accuracy_score
accuracy=accuracy_score(Y_TRAIN, y_pred)
print("The accuracy of prediction on s is ", accuracy)
# Out:
# The accuracy of prediction on s is  0.9268595645184861

# %% [markdown]
# ## Confusion Metrix

# %%
from sklearn.metrics import classification_report,confusion_matrix
confusion_matrix(Y_TRAIN, y_pred)
# Out:
# array([[6157,  695],
#        [ 306, 6528]], dtype=int64)

# %%
import matplotlib.pyplot as plt
cm = confusion_matrix(Y_TRAIN, y_pred)
fig, ax= plt.subplots(figsize=(4,4))
ax.imshow(cm)
ax.xaxis.set(ticks=(0,1), ticklabels=('predicted 0s','predicted 1s'))
ax.yaxis.set(ticks=(0,1), ticklabels=('Actual 0s','Actual 1s'))  
ax.set_ylim(1.5 ,-0.5)
for i in range(2):
    for j in range(2):
        ax.text(j,i,cm[i,j],  color='red')
plt.show()

# %% [markdown]
# ## Model Testing

# %%
# Make predictions on the testing data 
y_pred = Aroosa.predict(X_TEST)
print(y_pred)
# Out:
# [1 1 1 ... 1 1 1]

# %%
print(Y_TEST)
# Out:
# 11225    1
# 16263    1
# 15953    1
# 4810     0
# 12672    1
#         ..
# 5698     0
# 15869    1
# 1046     0
# 15516    1
# 3854     0
# Name: type of avocado, Length: 4563, dtype: int32

# %% [markdown]
# ## Accuracy of Testing

# %%
from sklearn.metrics import accuracy_score
accuracy=accuracy_score(Y_TEST, y_pred)
print("The accuracy of prediction on s is ", accuracy)
# Out:
# The accuracy of prediction on s is  0.9243918474687706

# %% [markdown]
# ## Confusion matrix

# %%
from sklearn.metrics import classification_report,confusion_matrix
confusion_matrix(Y_TEST, y_pred)
# Out:
# array([[2026,  248],
#        [  97, 2192]], dtype=int64)

# %%
import matplotlib.pyplot as plt
cm = confusion_matrix(Y_TEST, y_pred)
fig, ax= plt.subplots(figsize=(4,4))
ax.imshow(cm)
ax.xaxis.set(ticks=(0,1), ticklabels=('predicted 0s','predicted 1s'))
ax.yaxis.set(ticks=(0,1), ticklabels=('Actual 0s','Actual 1s'))  
ax.set_ylim(1.5 ,-0.5)
for i in range(2):
    for j in range(2):
        ax.text(j,i,cm[i,j],  color='red')
plt.show()

# %% [markdown]
# ## Classification Report

# %%
report=classification_report(Y_TEST,y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.89      0.92      2274
#            1       0.90      0.96      0.93      2289
#
#     accuracy                           0.92      4563
#    macro avg       0.93      0.92      0.92      4563
# weighted avg       0.93      0.92      0.92      4563

# %% [markdown]
# # 4.Decision Tree Model

# %% [markdown]
# ## Model Training

# %%
# import the classifier
from sklearn.tree import DecisionTreeClassifier

# create a classifier object
Aroosa= DecisionTreeClassifier(random_state=25, max_depth=3)

# fit the classifier with X and Y data
Aroosa.fit(X_TRAIN ,Y_TRAIN)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=25)

# %%
y_pred=Aroosa.predict(X_TRAIN)
print(y_pred)
# Out:
# [0 0 0 ... 0 0 0]

# %%
print(Y_TRAIN)
# Out:
# 5208     0
# 18131    1
# 1539     0
# 4401     0
# 812      0
#         ..
# 7324     0
# 1160     0
# 1175     0
# 2934     0
# 6618     0
# Name: type of avocado, Length: 13686, dtype: int32

# %% [markdown]
# ## Training Accuracy

# %%
from sklearn.metrics import accuracy_score
accuracy= accuracy_score(Y_TRAIN,y_pred)
print("The Accuracy of Prediction on S is ", accuracy)
# Out:
# The Accuracy of Prediction on S is  0.8965366067514248

# %% [markdown]
# ## Confusion Metrix

# %%
from sklearn.metrics import classification_report,confusion_matrix
confusion_matrix(Y_TRAIN, y_pred)
# Out:
# array([[6486,  366],
#        [1050, 5784]], dtype=int64)

# %%
import matplotlib.pyplot as plt
cm = confusion_matrix(Y_TRAIN, y_pred)
fig, ax= plt.subplots(figsize=(4,4))
ax.imshow(cm)
ax.xaxis.set(ticks=(0,1), ticklabels=('predicted 0s','predicted 1s'))
ax.yaxis.set(ticks=(0,1), ticklabels=('Actual 0s','Actual 1s'))  
ax.set_ylim(1.5 ,-0.5)
for i in range(2):
    for j in range(2):
        ax.text(j,i,cm[i,j],  color='blue')
plt.show()

# %% [markdown]
# ## Model Testing

# %%
y_pred=Aroosa.predict(X_TEST)
print(y_pred)
# Out:
# [1 1 0 ... 0 1 1]

# %%
print(Y_TEST)
# Out:
# 11225    1
# 16263    1
# 15953    1
# 4810     0
# 12672    1
#         ..
# 5698     0
# 15869    1
# 1046     0
# 15516    1
# 3854     0
# Name: type of avocado, Length: 4563, dtype: int32

# %% [markdown]
# ## Testing Accuracy

# %%
from sklearn.metrics import accuracy_score
accuracy= accuracy_score(Y_TEST,y_pred)
print("The Accuracy of Prediction on S is ", accuracy)
# Out:
# The Accuracy of Prediction on S is  0.8961209730440499

# %% [markdown]
# ## Confusion Metrix

# %%
from sklearn.metrics import classification_report,confusion_matrix
confusion_matrix(Y_TEST, y_pred)
# Out:
# array([[2145,  129],
#        [ 345, 1944]], dtype=int64)

# %%
import matplotlib.pyplot as plt
cm = confusion_matrix(Y_TEST, y_pred)
fig, ax= plt.subplots(figsize=(4,4))
ax.imshow(cm)
ax.xaxis.set(ticks=(0,1), ticklabels=('predicted 0s','predicted 1s'))
ax.yaxis.set(ticks=(0,1), ticklabels=('Actual 0s','Actual 1s'))  
ax.set_ylim(1.5 ,-0.5)
for i in range(2):
    for j in range(2):
        ax.text(j,i,cm[i,j],  color='blue')
plt.show()

# %% [markdown]
# ## Visualizing Tree

# %%
from sklearn import tree
import matplotlib.pyplot as plt
fig=plt.figure(figsize=(50, 30))
_=tree.plot_tree(Aroosa, feature_names=df.columns, filled=True)

# %% [markdown]
# ## Classification Report

# %%
report=classification_report(Y_TEST,y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.94      0.90      2274
#            1       0.94      0.85      0.89      2289
#
#     accuracy                           0.90      4563
#    macro avg       0.90      0.90      0.90      4563
# weighted avg       0.90      0.90      0.90      4563

# %% [markdown]
# # 5.Random Forest Classifier Model

# %% [markdown]
# ## Model Training

# %%
from sklearn.ensemble import RandomForestClassifier
Aroosa= RandomForestClassifier(n_estimators=25, random_state=25)
# fit the classifier with X and Y data
Aroosa.fit(X_TRAIN ,Y_TRAIN)
# Out:
# RandomForestClassifier(n_estimators=25, random_state=25)

# %%
y_pred = Aroosa.predict(X_TRAIN)
print(y_pred)
# Out:
# [0 1 0 ... 0 0 0]

# %%
print(Y_TRAIN)
# Out:
# 5208     0
# 18131    1
# 1539     0
# 4401     0
# 812      0
#         ..
# 7324     0
# 1160     0
# 1175     0
# 2934     0
# 6618     0
# Name: type of avocado, Length: 13686, dtype: int32

# %% [markdown]
# ## Training Accuracy

# %%
from sklearn.metrics import accuracy_score
accuracy= accuracy_score(Y_TRAIN,y_pred)
print("The Accuracy of Prediction on S is ", accuracy)
# Out:
# The Accuracy of Prediction on S is  0.9998538652637732

# %% [markdown]
# ## Confusion Metrix

# %%
from sklearn.metrics import classification_report,confusion_matrix
confusion_matrix(Y_TRAIN, y_pred)
# Out:
# array([[6851,    1],
#        [   1, 6833]], dtype=int64)

# %%
import matplotlib.pyplot as plt
cm = confusion_matrix(Y_TRAIN, y_pred)
fig, ax= plt.subplots(figsize=(4,4))
ax.imshow(cm)
ax.xaxis.set(ticks=(0,1), ticklabels=('predicted 0s','predicted 1s'))
ax.yaxis.set(ticks=(0,1), ticklabels=('Actual 0s','Actual 1s'))  
ax.set_ylim(1.5 ,-0.5)
for i in range(2):
    for j in range(2):
        ax.text(j,i,cm[i,j],  color='blue')
plt.show()

# %% [markdown]
# ## Model Testing

# %%
y_pred = Aroosa.predict(X_TEST)
print(y_pred)
# Out:
# [1 1 1 ... 0 1 0]

# %%
print(Y_TEST)
# Out:
# 11225    1
# 16263    1
# 15953    1
# 4810     0
# 12672    1
#         ..
# 5698     0
# 15869    1
# 1046     0
# 15516    1
# 3854     0
# Name: type of avocado, Length: 4563, dtype: int32

# %% [markdown]
# ## Testing Accuracy

# %%
from sklearn.metrics import accuracy_score
accuracy= accuracy_score(Y_TEST,y_pred)
print("The Accuracy of Prediction on S is ", accuracy)
# Out:
# The Accuracy of Prediction on S is  0.9853166776243699

# %% [markdown]
# ## Confusion Metrix

# %%
from sklearn.metrics import classification_report,confusion_matrix
confusion_matrix(Y_TEST, y_pred)
# Out:
# array([[2240,   34],
#        [  33, 2256]], dtype=int64)

# %%
import matplotlib.pyplot as plt
cm = confusion_matrix(Y_TEST, y_pred)
fig, ax= plt.subplots(figsize=(4,4))
ax.imshow(cm)
ax.xaxis.set(ticks=(0,1), ticklabels=('predicted 0s','predicted 1s'))
ax.yaxis.set(ticks=(0,1), ticklabels=('Actual 0s','Actual 1s'))  
ax.set_ylim(1.5 ,-0.5)
for i in range(2):
    for j in range(2):
        ax.text(j,i,cm[i,j],  color='blue')
plt.show()

# %% [markdown]
# ## Classification Report

# %%
report=classification_report(Y_TEST,y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      2274
#            1       0.99      0.99      0.99      2289
#
#     accuracy                           0.99      4563
#    macro avg       0.99      0.99      0.99      4563
# weighted avg       0.99      0.99      0.99      4563

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# assuming regressor is your trainned random forest model
# pick one tree from the forest ,e.g the first tree(index 0)
tree_to_plot = Aroosa.estimators_[0]

# plot the decision tree
plt.figure(figsize=(20,10))
plot_tree(tree_to_plot, feature_names=df.columns.tolist(), filled=True, rounded=True, fontsize=10)
plt.title("Decision Tree from Random Forest")
plt.show()

# %% [markdown]
# # Conclusion

# %%
1.Gussion Naiye Bayes:
    Training Accuracy= 0.69
    Testing Accuracy = 0.69
2.Logistic Regression:
    Training Accuracy= 0.90
    Testing Accuracy = 0.90
2.Support Vector Machine Classifier:
    Training Accuracy= 0.92
    Testing Accuracy = 0.92
3.Decision Tree Classifier:
    Training Accuracy= 0.89
    Testing Accuracy = 0.89
4.Random Forest Classifier:
    Training accuracy= 0.99
    Testing accuracy=  0.98

# %% [markdown]
# ## Which Model is Performed Best for your Classification Model

# %%
Random Forest Classifier.
Training accuracy= 0.99
Testing accuracy=  0.98
